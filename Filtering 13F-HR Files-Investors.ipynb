# %%
 # %config Completer.use_jedi = False

# %%
import networkx as nx
import community as c
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir('/Users/Natalia/Desktop/Master/Feb-2021/Modern Data Analytics/Project/All Fillings')

# %% [markdown]
# Files with all of the fillings from one period

# %%
quarter=pd.read_csv('1Q_2021_All.csv')
investors=pd.read_csv('investors.csv')

# %% [markdown]
# Principal investors in farmaceutical companies in the first quarter of 2021

# %%
inv=investors["investor"].tolist()
inv
# Out:
# ['BERKSHIRE ASSET MANAGEMENT LLC/PA',
#  'BlackRock Inc.',
#  'CREDIT SUISSE AG/',
#  'DRW Securities, LLC',
#  'FMR LLC',
#  'JANUS HENDERSON GROUP PLC',
#  'Nuveen Asset Management, LLC',
#  'Ally Financial Inc.',
#  'KORNITZER CAPITAL MANAGEMENT INC /KS',
#  'Kovitz Investment Group Partners, LLC',
#  'McGinn Investment Management, Inc.',
#  'PARAMETRIC PORTFOLIO ASSOCIATES LLC',
#  'PNC FINANCIAL SERVICES GROUP, INC.',
#  'Pacer Advisors, Inc.',
#  'BAILLIE GIFFORD & CO',
#  'BANK OF AMERICA CORP /DE/',
#  'CALIFORNIA PUBLIC EMPLOYEES RETIREMENT SYSTEM',
#  'GOLDMAN SACHS GROUP INC',
#  'HAP Trading, LLC',
#  'HILLHOUSE CAPITAL ADVISORS, LTD.',
#  'Laurion Capital Management LP',
#  'MILLENNIUM MANAGEMENT LLC',
#  'MORGAN STANLEY',
#  'PLATINUM INVESTMENT MANAGEMENT LTD',
#  'PRICE T ROWE ASSOCIATES INC /MD/',
#  'SG3 Management, LLC',
#  'Capital World Investors',
#  'DIAMOND HILL CAPITAL MANAGEMENT INC',
#  'First American Bank',
#  'LETKO, BROSSEAU & ASSOCIATES INC',
# ...

# %%
quarter
# Out:
#          Unnamed: 0                         name      cik state  \
# 0                 0  Pensionfund DSM Netherlands  1297731    P7
# 1                 1  Pensionfund DSM Netherlands  1297731    P7
# 2                 2  Pensionfund DSM Netherlands  1297731    P7
# 3                 3  Pensionfund DSM Netherlands  1297731    P7
# 4                 4  Pensionfund DSM Netherlands  1297731    P7
# ...             ...                          ...      ...   ...
# 2198425     2198425                 SWS Partners  1731731    OH
# 2198426     2198426                 SWS Partners  1731731    OH
# 2198427     2198427                 SWS Partners  1731731    OH
# 2198428     2198428                 SWS Partners  1731731    OH
# 2198429     2198429                 SWS Partners  1731731    OH
#
#                                       issuers     cussip  shares shares_type
# 0                                       3M CO  88579Y101   21700          SH
# ...

# %% [markdown]
# If there is shares bellow 10, we assume there is an error and those entries are removed

# %%
quarter['shares']=[float(i) for i in quarter['shares']]
quarter = quarter[quarter.shares >= 10]
quarter
# Out:
#          Unnamed: 0                         name      cik state  \
# 0                 0  Pensionfund DSM Netherlands  1297731    P7
# 1                 1  Pensionfund DSM Netherlands  1297731    P7
# 2                 2  Pensionfund DSM Netherlands  1297731    P7
# 3                 3  Pensionfund DSM Netherlands  1297731    P7
# 4                 4  Pensionfund DSM Netherlands  1297731    P7
# ...             ...                          ...      ...   ...
# 2198425     2198425                 SWS Partners  1731731    OH
# 2198426     2198426                 SWS Partners  1731731    OH
# 2198427     2198427                 SWS Partners  1731731    OH
# 2198428     2198428                 SWS Partners  1731731    OH
# 2198429     2198429                 SWS Partners  1731731    OH
#
#                                       issuers     cussip    shares shares_type
# 0                                       3M CO  88579Y101   21700.0          SH
# ...

# %% [markdown]
# We keep only the observations for the investors listes above

# %%
quarter_filtered_investor=quarter[quarter['name'].isin(inv)]
quarter_filtered_investor
# Out:
#          Unnamed: 0                               name      cik state  \
# 3536           3536     Neumann Advisory Hong Kong Ltd  1727862    K3
# 3537           3537     Neumann Advisory Hong Kong Ltd  1727862    K3
# 3538           3538     Neumann Advisory Hong Kong Ltd  1727862    K3
# 3539           3539     Neumann Advisory Hong Kong Ltd  1727862    K3
# 3540           3540     Neumann Advisory Hong Kong Ltd  1727862    K3
# ...             ...                                ...      ...   ...
# 2018691     2018691  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
# 2018692     2018692  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
# 2018693     2018693  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
# 2018694     2018694  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
# 2018695     2018695  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
#
#                                issuers     cussip     shares shares_type
# ...

# %% [markdown]
# And then, only their investments in pharmaceutical companies

# %%
phar_2 = quarter_filtered_investor[quarter_filtered_investor['issuers'].str.contains('pfizer', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('astrazeneca', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('moderna', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('sinovac', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('curevac', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('merck', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('themis', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('glaxosmithkline', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('novartis', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('roche', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('sanofi', na = False, case=False) |
       quarter_filtered_investor['issuers'].str.contains('bayer', na = False, case=False)]

phar_2
# Out:
#          Unnamed: 0                               name      cik state  \
# 3543           3543     Neumann Advisory Hong Kong Ltd  1727862    K3
# 4319           4319                First American Bank  1291422    IL
# 4387           4387                First American Bank  1291422    IL
# 4388           4388                First American Bank  1291422    IL
# 4417           4417                First American Bank  1291422    IL
# ...             ...                                ...      ...   ...
# 2014526     2014526                  DEUTSCHE BANK AG\   948046    2M
# 2014990     2014990                  DEUTSCHE BANK AG\   948046    2M
# 2018493     2018493  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
# 2018585     2018585  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
# 2018609     2018609  BERKSHIRE ASSET MANAGEMENT LLC/PA   949012    PA
#
#                               issuers     cussip     shares shares_type
# ...

# %%
phar_2.loc[phar_2['issuers'].str.contains('pfizer', case=False, na=False), 'issuers']= 'Pfizer'
phar_2.loc[phar_2['issuers'].str.contains('astrazeneca', case=False, na=False), 'issuers'] = 'Astrazeneca'
phar_2.loc[phar_2['issuers'].str.contains('moderna', case=False, na=False), 'issuers'] = 'Moderna'
phar_2.loc[phar_2['issuers'].str.contains('sinovac', case=False, na=False), 'issuers'] = 'Sinovac'
phar_2.loc[phar_2['issuers'].str.contains('curevac', case=False, na=False), 'issuers'] = 'Curevac'
phar_2.loc[phar_2['issuers'].str.contains('merck', case=False, na=False), 'issuers'] = 'Merck'
phar_2.loc[phar_2['issuers'].str.contains('themis', case=False, na=False), 'issuers'] = 'Themis'
phar_2.loc[phar_2['issuers'].str.contains('glaxosmithkline', case=False, na=False), 'issuers'] = 'Glaxosmithkline'
phar_2.loc[phar_2['issuers'].str.contains('novartis', case=False, na=False), 'issuers'] = 'Novartis'
phar_2.loc[phar_2['issuers'].str.contains('roche', case=False, na=False), 'issuers'] = 'Roche'
phar_2.loc[phar_2['issuers'].str.contains('sanofi', case=False, na=False), 'issuers'] = 'Sanofi'
phar_2.loc[phar_2['issuers'].str.contains('bayer', case=False, na=False), 'issuers'] = 'Bayer'
phar_2
# Out:
# C:\Users\Natalia\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#          Unnamed: 0                               name      cik state  \
# 3543           3543     Neumann Advisory Hong Kong Ltd  1727862    K3
# 4319           4319                First American Bank  1291422    IL
# 4387           4387                First American Bank  1291422    IL
# 4388           4388                First American Bank  1291422    IL
# 4417           4417                First American Bank  1291422    IL
# ...             ...                                ...      ...   ...
# 2014526     2014526                  DEUTSCHE BANK AG\   948046    2M
# ...

# %%
os.chdir('/Users/Natalia/Desktop/Master/Feb-2021/Modern Data Analytics/Project/Filtered Fillings')

# %%
phar_2.to_csv('2021Q1_Filtered.csv',index=False)

# %%
phar_2 = pd.
